# %%
import matplotlib.pyplot as plt
import numpy as np
import torch as pt
import torch.nn as nn

# %%
def V_step(V, F, dt):
    """
    Computes next position given current position and forcing inputs
    V: car's current position in 6D space, (x , y, theta, s, omega, t)
    F: current forcing inputs, (phi, psi, dt)
    """
    phi = F[0]  # linear acceleration
    psi = F[1]  # angluar acceleration
    dt2 = dt*dt/2

    x = V[0]    # x coordinate
    y = V[1]    # y coordinate
    a = V[2]    # angle
    s = V[3]    # speed
    w = V[4]    # angular speed
    t = V[5]    # time

    _0 = pt.zeros_like(x)
    _1 = pt.ones_like(x)

    A1 = pt.stack([x, y, a, s, w, t])
    A2 = pt.stack([s*pt.cos(a), s*pt.sin(a), w, _0, _0, _0])
    A3 = pt.stack([-s*w*pt.sin(a), s*w*pt.cos(a), _0, _0, _0, _0])
    A = A1 + dt*A2 + dt2*A3

    B2 = pt.stack([_0, _0, _0, _1, _0, _0])
    B3 = pt.stack([pt.cos(a), pt.sin(a), _0, _0, _0, _0])
    B = dt*B2 + dt2*B3

    C2 = pt.stack([_0, _0, _0, _0, _1, _0])
    C3 = pt.stack([_0, _0, _1, _0, _0, _0])
    C = dt*C2 + dt2*C3

    D = pt.stack([_0, _0, _0, _0, _0, _1])  # this is correct

    return A + phi*B + psi*C + dt*D

def loss_fun(Y, T, F, scale=None):
    scale = pt.tensor([1, 1, 1, 1, 1]) if scale is None else scale
    diff = (Y[0:5]-T) * scale
    target_loss = pt.dot(diff, diff)                # loss from missing the target
    time_loss = Y[5]                                # loss by taking too long
    l2_loss = pt.mean(F[:,0:2]**2)                  # loss by using too much force
    return target_loss, time_loss, l2_loss

def get_forcing(V, F):
    # limits based on current speed

    S = abs(V[...,3])
    turningRadius = 1

    psi_lim = pt.min(S / turningRadius, 0.8 * pt.ones_like(S))

    F_limited = pt.stack([
        pt.clamp(F[...,0], -0.8, 0.8),
        pt.clamp(F[...,1], -psi_lim, psi_lim)
        ], dim=-1)

    return F_limited

# Compute a path while modifing V_mat and F_mat inplace
def compute_path_autograd(V0, F_request, target, dt):
    V_list = [V0]
    F_true = []

    for i in range(F_request.shape[0]):
        F_true.append(get_forcing(V_list[i], F_request[i]))
        V_list.append(V_step(V_list[i], F_true[i], dt))
        # with pt.no_grad():
        #     F_request.data[i] = F_true[i]

    loss = loss_fun(V_list[-1], target, F_request)


    return V_list, loss

def to_tensor(V_mat):
    ten = pt.zeros((len(V_mat), V_mat[0].shape[0]))
    for i in range(len(V_mat)):
        ten[i] = V_mat[i].detach().cpu()
    return ten[:,0:5], ten[:,5]

# %%
def plot_traj(V_records, target, alphas=None, ax=None, figsize=(8,6)):
    num_records = V_records.shape[0]

    if alphas is None:
        alphas = np.ones(num_records)
        alphas[:-1] = np.linspace(0.1, 0.8, num_records-1)
    
    arrowDir = lambda V: (V[3]*np.cos(V[2]), V[3]*np.sin(V[2]))

    fig_exists = False

    if ax is None:
        fig, ax = plt.subplots(1,1,figsize=figsize)
        fig_exists = True
    
    ax.scatter(V_records[0,0,0], V_records[0,0,1], marker='*', color='sandybrown', s=200, zorder=6, label='Start')
    ax.scatter(target[0], target[1], marker='s', color='sandybrown', s=120, label='Target')
    ax.scatter(V_records[-1,-1,0], V_records[-1,-1,1], marker='o', color='dodgerblue', s=120, zorder=10, label='End')


    ax.arrow(*V_records[0,0,0:2], *arrowDir(V_records[0,0]), color='sandybrown', head_width=0.15, head_length=0.15, lw=4, zorder=2)
    ax.arrow(*target[0:2], *arrowDir(target.numpy()), color='sandybrown', head_width=0.15, head_length=0.15, lw=4, zorder=2)
    ax.arrow(*V_records[-1,-1,0:2], *arrowDir(V_records[-1,-1]), color='dodgerblue', head_width=0.1, head_length=0.1, lw=3, zorder=2)

    for i in range(num_records):
        lw = 1 if alphas[i] != 1 else 2
        ax.plot(V_records[i,:,0], V_records[i,:,1], color='dodgerblue', lw=lw, alpha=alphas[i])

    ax.set_title('Trajectory')
    ax.set_xlabel('X Position')
    ax.set_ylabel('Y Position')
    ax.axis('equal')
    ax.grid()
    ax.legend()

    return (fig, ax) if fig_exists is True else ax


def plot_forcing(F_records, ts_records, alphas=None, ax=None, figsize=(8,6)):
    num_records = F_records.shape[0]

    if alphas is None:
        alphas = np.ones(num_records)
        alphas[:-1] = np.linspace(0.1, 0.8, num_records-1)
    
    fig_exists = False
    if ax is None:
        fig, ax = plt.subplots(1,1,figsize=figsize)
        fig_exists = True

    for i in range(num_records-1):
        lw = 1.5 if alphas[i] != 1 else 2
        plt.plot(ts_records[i,:-1].detach().numpy(), F_records[i,:,0].detach().numpy(), color='deeppink', lw=lw, alpha=alphas[i])
        plt.plot(ts_records[i,:-1].detach().numpy(), F_records[i,:,1].detach().numpy(), color='limegreen', lw=lw, alpha=alphas[i])
    
    lw = 1 if alphas[i] != 1 else 2
    plt.plot(ts_records[-1,:-1].detach().numpy(), F_records[-1,:,0].detach().numpy(), color='deeppink', lw=lw, alpha=alphas[-1], label='Acceleration Force')
    plt.plot(ts_records[-1,:-1].detach().numpy(), F_records[-1,:,1].detach().numpy(), color='limegreen', lw=lw, alpha=alphas[-1], label='Turning Force')

    left, right = ax.get_xlim()
    ax.plot([left, right], [0.8, 0.8], '--k', lw=1.5)
    ax.plot([left, right], [-0.8, -0.8], '--k', lw=1.5)
    
    ax.legend()
    ax.set_title('Forcing Terms')
    ax.set_xlabel('Time')
    ax.set_ylabel('Force')
    ax.set_ylim([-0.85, 0.85])
    ax.grid()

    return (fig, ax) if fig_exists is True else ax

# %% [markdown]
# ### Sensitive to ICs

# %% [markdown]
# #### Zero IC

# %%
t0 = 0
tf = 9
n_steps = 32
dt = (tf-t0)/n_steps
print(f'Path has {n_steps} steps with size {dt:0.3g}s')

v0 = pt.tensor([0, 0, 0.2, 1, 1, t0], requires_grad=True)
target = pt.tensor([5.68071168, 2.5029068, -1.8625, 2.375, -1.75])

F_mat = nn.Parameter(0*pt.randn((n_steps, 2)))
V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)

optim = pt.optim.AdamW([F_mat], lr=6e-2, weight_decay=0)


pt.autograd.set_detect_anomaly(False)

figaxs = None
iters = 1000
plot_freq = 50
num_records = iters//plot_freq if iters%plot_freq == 0 else iters//plot_freq + 1

V_records = pt.zeros((num_records, n_steps+1, 5))
F_records = pt.zeros((num_records, n_steps, 2))
ts_records = pt.zeros((num_records, n_steps+1))

for i in range(iters):
    is_record_step = (i % plot_freq == plot_freq - 1) or (i== iters - 1)
    record_idx = i // plot_freq
    
    optim.zero_grad()
    V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)


    dist = target_loss ** 0.5

    loss = target_loss
    loss.backward()
    optim.step()

    with pt.no_grad():
        F_mat.copy_(get_forcing(pt.stack(V_mat[:-1]), F_mat))

    if i % plot_freq == plot_freq-1:
        print(f"Iteration {i+1}, Target Dist: {target_loss ** 0.5:.3f}")
        if i < iters-1:
            traj, ts = to_tensor(V_mat)
            V_records[record_idx,:,:] = traj
            F_records[record_idx,:,:].copy_(F_mat)
            ts_records[record_idx,:] = ts

traj, ts = to_tensor(V_mat)
traj, ts = to_tensor(V_mat)
V_records[record_idx,:,:] = traj
F_records[record_idx,:,:].copy_(F_mat)
ts_records[record_idx,:] = ts
# Out:
# Path has 32 steps with size 0.281s
# Iteration 50, Target Dist: 6.542
# Iteration 100, Target Dist: 5.906
# Iteration 150, Target Dist: 5.568
# Iteration 200, Target Dist: 5.328
# Iteration 250, Target Dist: 5.103
# Iteration 300, Target Dist: 4.867
# Iteration 350, Target Dist: 4.739
# Iteration 400, Target Dist: 4.548
# Iteration 450, Target Dist: 4.371
# Iteration 500, Target Dist: 4.200
# Iteration 550, Target Dist: 3.883
# Iteration 600, Target Dist: 3.616
# Iteration 650, Target Dist: 3.362
# Iteration 700, Target Dist: 2.928
# Iteration 750, Target Dist: 2.748
# Iteration 800, Target Dist: 2.558
# Iteration 850, Target Dist: 2.422
# Iteration 900, Target Dist: 2.366
# Iteration 950, Target Dist: 2.310
# Iteration 1000, Target Dist: 2.251

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4), dpi=300)
plot_traj(V_records, target, ax=ax1)
plot_forcing(F_records, ts_records, ax=ax2)
plt.show()

# %% [markdown]
# #### Random ICs

# %%
t0 = 0
tf = 9
n_steps = 32
dt = (tf-t0)/n_steps
print(f'Path has {n_steps} steps with size {dt:0.3g}s')

v0 = pt.tensor([0, 0, 0.2, 1, 1, t0], requires_grad=True)
target = pt.tensor([5.68071168, 2.5029068, -1.8625, 2.375, -1.75])

F_mat_init = pt.randn((n_steps, 2))

F_mat = nn.Parameter(F_mat_init.clone().detach())
V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)

optim = pt.optim.AdamW([F_mat], lr=6e-2, weight_decay=0)


pt.autograd.set_detect_anomaly(False)

figaxs = None
iters = 1000
plot_freq = 50
num_records = iters//plot_freq if iters%plot_freq == 0 else iters//plot_freq + 1

V_records = pt.zeros((num_records, n_steps+1, 5))
F_records = pt.zeros((num_records, n_steps, 2))
ts_records = pt.zeros((num_records, n_steps+1))

for i in range(iters):
    is_record_step = (i % plot_freq == plot_freq - 1) or (i== iters - 1)
    record_idx = i // plot_freq
    
    optim.zero_grad()
    V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)


    dist = target_loss ** 0.5

    loss = target_loss
    loss.backward()
    optim.step()

    with pt.no_grad():
        F_mat.copy_(get_forcing(pt.stack(V_mat[:-1]), F_mat))

    if i % plot_freq == plot_freq-1:
        print(f"Iteration {i+1}, Target Dist: {target_loss ** 0.5:.3f}")
        if i < iters-1:
            traj, ts = to_tensor(V_mat)
            V_records[record_idx,:,:] = traj
            F_records[record_idx,:,:].copy_(F_mat)
            ts_records[record_idx,:] = ts

traj, ts = to_tensor(V_mat)
traj, ts = to_tensor(V_mat)
V_records[record_idx,:,:] = traj
F_records[record_idx,:,:].copy_(F_mat)
ts_records[record_idx,:] = ts

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4), dpi=300)
plot_traj(V_records, target, ax=ax1)
plot_forcing(F_records, ts_records, ax=ax2)
plt.show()
# Out:
# Path has 32 steps with size 0.281s
# Iteration 50, Target Dist: 0.872
# Iteration 100, Target Dist: 0.262
# Iteration 150, Target Dist: 0.120
# Iteration 200, Target Dist: 0.059
# Iteration 250, Target Dist: 0.028
# Iteration 300, Target Dist: 0.012
# Iteration 350, Target Dist: 0.006
# Iteration 400, Target Dist: 0.003
# Iteration 450, Target Dist: 0.002
# Iteration 500, Target Dist: 0.001
# Iteration 550, Target Dist: 0.000
# Iteration 600, Target Dist: 0.000
# Iteration 650, Target Dist: 0.000
# Iteration 700, Target Dist: 0.000
# Iteration 750, Target Dist: 0.000
# Iteration 800, Target Dist: 0.000
# Iteration 850, Target Dist: 0.000
# Iteration 900, Target Dist: 0.000
# Iteration 950, Target Dist: 0.000
# Iteration 1000, Target Dist: 0.000

# %% [markdown]
# ### Introducing L2 regularization on $\phi$ and $\psi$

# %%
t0 = 0
tf = 9
n_steps = 32
dt = (tf-t0)/n_steps
print(f'Path has {n_steps} steps with size {dt:0.3g}s')

v0 = pt.tensor([0, 0, 0.2, 1, 1, t0], requires_grad=True)
target = pt.tensor([5.68071168, 2.5029068, -1.8625, 2.375, -1.75])

F_mat = nn.Parameter(F_mat_init.clone().detach())
V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)

optim = pt.optim.AdamW([F_mat], lr=6e-2, weight_decay=0)


pt.autograd.set_detect_anomaly(False)

iters = 1000
plot_freq = 50
num_records = iters//plot_freq if iters%plot_freq == 0 else iters//plot_freq + 1

V_records = pt.zeros((num_records, n_steps+1, 5))
F_records = pt.zeros((num_records, n_steps, 2))
ts_records = pt.zeros((num_records, n_steps+1))

for i in range(iters):
    is_record_step = (i % plot_freq == plot_freq - 1) or (i== iters - 1)
    record_idx = i // plot_freq
    
    optim.zero_grad()
    V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)


    dist = target_loss ** 0.5

    l2_coef = 4e0

    loss = target_loss + l2_coef*l2_loss
    loss.backward()
    optim.step()

    with pt.no_grad():
        F_mat.copy_(get_forcing(pt.stack(V_mat[:-1]), F_mat))

    if i % plot_freq == plot_freq-1:
        print(f"Iteration {i+1}, Target Dist: {target_loss ** 0.5:.3f}")
        if i < iters-1:
            traj, ts = to_tensor(V_mat)
            V_records[record_idx,:,:] = traj
            F_records[record_idx,:,:].copy_(F_mat)
            ts_records[record_idx,:] = ts

traj, ts = to_tensor(V_mat)
traj, ts = to_tensor(V_mat)
V_records[record_idx,:,:] = traj
F_records[record_idx,:,:].copy_(F_mat)
ts_records[record_idx,:] = ts

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4), dpi=300)
plot_traj(V_records, target, ax=ax1)
plot_forcing(F_records, ts_records, ax=ax2)
plt.show()
# Out:
# Path has 32 steps with size 0.281s
# Iteration 50, Target Dist: 0.701
# Iteration 100, Target Dist: 0.280
# Iteration 150, Target Dist: 0.235
# Iteration 200, Target Dist: 0.226
# Iteration 250, Target Dist: 0.219
# Iteration 300, Target Dist: 0.214
# Iteration 350, Target Dist: 0.211
# Iteration 400, Target Dist: 0.209
# Iteration 450, Target Dist: 0.208
# Iteration 500, Target Dist: 0.330
# Iteration 550, Target Dist: 0.206
# Iteration 600, Target Dist: 0.206
# Iteration 650, Target Dist: 0.289
# Iteration 700, Target Dist: 0.208
# Iteration 750, Target Dist: 0.284
# Iteration 800, Target Dist: 0.376
# Iteration 850, Target Dist: 0.207
# Iteration 900, Target Dist: 0.291
# Iteration 950, Target Dist: 0.208
# Iteration 1000, Target Dist: 0.229

# %% [markdown]
# #### Use previously found smooth forcings as initial conditions for next step. Here we drop L2 regularization to improve target accuracy

# %%
t0 = 0
tf = 9
n_steps = 32
dt = (tf-t0)/n_steps
print(f'Path has {n_steps} steps with size {dt:0.3g}s')

v0 = pt.tensor([0, 0, 0.2, 1, 1, t0], requires_grad=True)
target = pt.tensor([5.68071168, 2.5029068, -1.8625, 2.375, -1.75])

F_mat = nn.Parameter(F_records[-1].clone().detach())
V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)

optim = pt.optim.AdamW([F_mat], lr=6e-2, weight_decay=0)


pt.autograd.set_detect_anomaly(False)

iters = 400
plot_freq = 50
num_records = iters//plot_freq if iters%plot_freq == 0 else iters//plot_freq + 1

V_records = pt.zeros((num_records, n_steps+1, 5))
F_records = pt.zeros((num_records, n_steps, 2))
ts_records = pt.zeros((num_records, n_steps+1))

for i in range(iters):
    is_record_step = (i % plot_freq == plot_freq - 1) or (i== iters - 1)
    record_idx = i // plot_freq
    
    optim.zero_grad()
    V_mat, (target_loss, time_loss, l2_loss) = compute_path_autograd(v0, F_mat, target, dt)


    dist = target_loss ** 0.5

    l2_coef = 0

    loss = target_loss
    loss.backward()
    optim.step()

    with pt.no_grad():
        F_mat.copy_(get_forcing(pt.stack(V_mat[:-1]), F_mat))

    if i % plot_freq == plot_freq-1:
        print(f"Iteration {i+1}, Target Dist: {target_loss ** 0.5:.3f}")
        if i < iters-1:
            traj, ts = to_tensor(V_mat)
            V_records[record_idx,:,:] = traj
            F_records[record_idx,:,:].copy_(F_mat)
            ts_records[record_idx,:] = ts

traj, ts = to_tensor(V_mat)
traj, ts = to_tensor(V_mat)
V_records[record_idx,:,:] = traj
F_records[record_idx,:,:].copy_(F_mat)
ts_records[record_idx,:] = ts

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10,4), dpi=300)
plot_traj(V_records, target, ax=ax1)
plot_forcing(F_records, ts_records, ax=ax2)
plt.show()
# Out:
# Path has 32 steps with size 0.281s
# Iteration 50, Target Dist: 1.031
# Iteration 100, Target Dist: 0.307
# Iteration 150, Target Dist: 0.150
# Iteration 200, Target Dist: 0.095
# Iteration 250, Target Dist: 0.057
# Iteration 300, Target Dist: 0.032
# Iteration 350, Target Dist: 0.017
# Iteration 400, Target Dist: 0.009
